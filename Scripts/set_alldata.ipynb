# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\RomarNathoeRepubliq\Documents\Uni\Thesis\Genes\Data\datasets123_allinfo.csv")

# %%
df.head()
# Out:
#    Dataset        GSE Condition Disease      Tissue      FAB  \
# 0      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
# 1      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
# 2      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
# 3      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
# 4      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
#
#                          Filename                              id      PAX8  \
# 0   AHW_ALL_BA_025919_13_A_PZ.CEL   AHW_ALL_BA_025919_13_A_PZ.CEL  9.221573
# 1   AHW_ALL_BA_032751_71_A_PZ.CEL   AHW_ALL_BA_032751_71_A_PZ.CEL  8.524435
# 2    AHW_ALL_BN_022495_7_A_PZ.CEL    AHW_ALL_BN_022495_7_A_PZ.CEL  8.606060
# 3  AHW_ALL_MLL_031351_13_A_PZ.CEL  AHW_ALL_MLL_031351_13_A_PZ.CEL  8.841501
# 4  AHW_ALL_MLL_036187_80_A_PZ.CEL  AHW_ALL_MLL_036187_80_A_PZ.CEL  8.882826
#
#        CCL5  ...      WNT6    RABEP2    FKBP15      LRCH4     MEX3D      BCAN  \
# 0  7.990144  ...  9.725984  6.468604  4.229163   9.617773  5.404848  7.871873
# 1  6.648112  ...  8.805910  7.236525  4.594555   9.652448  5.650710  7.179527
# 2  6.382602  ...  9.142436  7.937021  4.173806   9.792847  5.385639  7.652625
# 3  6.469583  ...  9.169173  8.361242  4.577759  10.470295  5.696314  7.594891
# 4  8.332415  ...  8.948210  8.229147  4.181408  10.439300  5.459417  7.480463
#
#         ACTB      GAPDH  MIR3648-2  MIR3648-1
# 0  11.430549  11.725073   6.373859   6.086670
# 1  10.928578  11.671908   6.572640   7.823704
# 2  11.297186  11.879521  11.165859  10.734375
# 3  12.156462  12.175835   9.551800   9.627878
# 4  10.509088  11.038747  11.295602  10.229529
#
# [5 rows x 12716 columns]

# %%
print(df["Disease"].value_counts())
print()
# Out:
# AML                                         4082
# ALL                                         3466
# healthy                                      907
# CLL                                          770
# COPD                                         323
# JIA                                          293
# MDS                                          267
# MS                                           240
# CML                                          162
# Infection                                    156
# TB.vaccination                               119
# Breast cancer                                109
# Dengue fever                                 101
# endarterectomy operation                      97
# Lyme disease                                  84
# Chronic Allograft Nephropathy                 77
# Diabetes Type I                               74
# influenca vaccination                         63
# AMKL                                          63
# SLE                                           61
# periodontitis                                 59
# Sepsis                                        54
# RSV Infection                                 51
# schizophrenia                                 43
# Sarcoidosis                                   40
# Diabetes Type II                              29
# immunosuppression                             24
# Plasmodium vivax challenge                    24
# unknown cancer                                22
# clinically isolated syndrome                  18
# Polycystic                                    16
# JDM                                           13
# Diabetes Type 1                               12
# transplant rejection                          12
# Hypertension, nephrosclerosis                 11
# Diabetes Type 2                                9
# RSV infection                                  8
# DS transient myeloproliferative disorder       8
# Glom-sclerosis,chr&unspecified                 7
# Unknown                                        6
# Hypersensitivity Pnemonitis                    6
# FSGS-Focal sclerosing GN                       6
# T.ALL                                          5
# Nephritis                                      4
# Cystinosis                                     4
# MPGN-membranoproliferative?typ                 3
# Thin basement membrane dz                      3
# Nephropathy, IgA (Bergers)                     3
# HRV infection                                  3
# Lupus (SLE)                                    3
# Wegener's Granulomatosis                       3
# Alport's/Famil Hered neph                      2
# GN-other chronicGlom.nephritis                 2
# GN-membranous glom.nephritis                   2
# Name: Disease, dtype: int64

# %%
df['target'] = [1 if (x == 'AML' or x == 'AMKL') else 0 for x in df['Disease']]

# %%
df.head()
# Out:
#    Dataset        GSE Condition Disease      Tissue      FAB  \
# 0      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
# 1      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
# 2      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
# 3      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
# 4      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
#
#                          Filename                              id      PAX8  \
# 0   AHW_ALL_BA_025919_13_A_PZ.CEL   AHW_ALL_BA_025919_13_A_PZ.CEL  9.221573
# 1   AHW_ALL_BA_032751_71_A_PZ.CEL   AHW_ALL_BA_032751_71_A_PZ.CEL  8.524435
# 2    AHW_ALL_BN_022495_7_A_PZ.CEL    AHW_ALL_BN_022495_7_A_PZ.CEL  8.606060
# 3  AHW_ALL_MLL_031351_13_A_PZ.CEL  AHW_ALL_MLL_031351_13_A_PZ.CEL  8.841501
# 4  AHW_ALL_MLL_036187_80_A_PZ.CEL  AHW_ALL_MLL_036187_80_A_PZ.CEL  8.882826
#
#        CCL5  ...    RABEP2    FKBP15      LRCH4     MEX3D      BCAN  \
# 0  7.990144  ...  6.468604  4.229163   9.617773  5.404848  7.871873
# 1  6.648112  ...  7.236525  4.594555   9.652448  5.650710  7.179527
# 2  6.382602  ...  7.937021  4.173806   9.792847  5.385639  7.652625
# 3  6.469583  ...  8.361242  4.577759  10.470295  5.696314  7.594891
# 4  8.332415  ...  8.229147  4.181408  10.439300  5.459417  7.480463
#
#         ACTB      GAPDH  MIR3648-2  MIR3648-1  target
# 0  11.430549  11.725073   6.373859   6.086670       0
# 1  10.928578  11.671908   6.572640   7.823704       0
# 2  11.297186  11.879521  11.165859  10.734375       0
# 3  12.156462  12.175835   9.551800   9.627878       0
# 4  10.509088  11.038747  11.295602  10.229529       0
#
# [5 rows x 12717 columns]

# %%
print(df["target"].value_counts())
print()
# Out:
# 0    7884
# 1    4145
# Name: target, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, test_size=0.1, random_state=0, stratify=df[['target']])

# %%
train.head()
# Out:
#        Dataset       GSE Condition        Disease      Tissue      FAB  \
# 10212      2.0  GSE27562   CONTROL  Breast cancer        PBMC  unknown
# 4153       2.0  GSE14468      CASE            AML  BM or PBMC       M5
# 10110      2.0  GSE27383   CONTROL        healthy        PBMC  unknown
# 665        1.0   GSE1159      CASE            AML  BM or PBMC  unknown
# 4976       2.0  GSE68790   CONTROL            ALL  BM or PBMC  unknown
#
#                       Filename                       id      PAX8       CCL5  \
# 10212            GSM682074.CEL            GSM682074.CEL  8.075370  11.281200
# 4153             GSM158989.CEL            GSM158989.CEL  8.996900   7.188690
# 10110      GSM677180_H28_2.CEL      GSM677180_H28_2.CEL  7.302110  12.072500
# 665               GSM20809.CEL             GSM20809.CEL  8.888127   7.080952
# 4976   GSM1681654_0232_K05.CEL  GSM1681654_0232_K05.CEL  7.598980   6.838650
#
#        ...   RABEP2    FKBP15      LRCH4    MEX3D     BCAN       ACTB  \
# 10212  ...  6.62000  4.109530   7.154650  3.78063  6.63703  12.640800
# 4153   ...  7.09163  5.126170   8.912010  3.63031  7.59313  13.493200
# 10110  ...  7.70961  5.601310   6.820760  4.11408  6.46324  13.177300
# 665    ...  6.87161  4.177303  10.345184  5.12289  7.69612  13.290466
# 4976   ...  7.16857  4.584060   7.332500  3.50825  7.29608   9.534770
#
#            GAPDH  MIR3648-2  MIR3648-1  target
# 10212  12.393300   5.815030   8.470640       0
# 4153   13.045800   5.103450   4.276990       1
# 10110  12.489000   7.789820   7.739070       0
# 665    13.179909   4.913232   5.427801       1
# 4976   12.764300   6.628460   6.927760       0
#
# [5 rows x 12717 columns]

# %%
test.head()
# Out:
#        Dataset                  GSE Condition Disease      Tissue      FAB  \
# 9449       2.0             GSE17855      CASE     AML  BM or PBMC  unknown
# 4051       2.0             GSE14468      CASE     AML  BM or PBMC       M5
# 769        1.0              GSE1159      CASE     AML  BM or PBMC  unknown
# 11367      3.0  Lavallee (GSE67039)      CASE     AML          BM  unknown
# 1177       1.0             GSE13425   CONTROL     ALL        PBMC  unknown
#
#             Filename             id      PAX8        CCL5  ...      RABEP2  \
# 9449   GSM446092.CEL  GSM446092.CEL  8.272890    8.039990  ...    7.595220
# 4051   GSM158884.CEL  GSM158884.CEL  8.317070    8.059250  ...    7.115450
# 769     GSM20915.CEL   GSM20915.CEL  8.694966    7.724316  ...    6.979153
# 11367     GSM1636733     GSM1636733  4.283865  647.917020  ...  450.041660
# 1177   GSM338689.CEL  GSM338689.CEL  8.914766    5.284705  ...    7.336827
#
#             FKBP15        LRCH4      MEX3D      BCAN           ACTB  \
# 9449      3.419600     8.560160   4.088040  7.552860      12.206000
# 4051      5.146010     7.639800   5.068390  6.868970      13.889400
# 769       5.241102    10.799278   4.569548  7.439056      13.351178
# 11367  3731.482765  4042.060376  72.524550  1.018917  158039.594917
# 1177      4.283219    10.352194   5.784377  7.772894      12.494687
#
#                GAPDH  MIR3648-2  MIR3648-1  target
# 9449       13.182400   5.965410   5.321470       1
# 4051       13.466800   6.839590   5.876310       1
# 769        13.108710  12.235879   9.016586       1
# 11367  111180.463745   1.099411   1.099411       1
# 1177       12.891293   5.499288   6.207734       0
#
# [5 rows x 12717 columns]

# %%
print(train["target"].value_counts())
print()
print(test["target"].value_counts())
print()
# Out:
# 0    7096
# 1    3730
# Name: target, dtype: int64
#
# 0    788
# 1    415
# Name: target, dtype: int64

# %%
train = train.drop(["Dataset", "GSE", "Condition", "Disease", "Tissue", "FAB", "Filename", "id"], axis = 1)

# %%
test = test.drop(["Dataset", "GSE", "Condition", "Disease", "Tissue", "FAB", "Filename", "id"], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-1786aa7069e0> in <module>
# ----> 1 test = test.drop(["Dataset", "GSE", "Condition", "Disease", "Tissue", "FAB", "Filename", "id"], axis = 1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Dataset' 'GSE' 'Condition' 'Disease' 'Tissue' 'FAB' 'Filename' 'id'] not found in axis"

# %%
train.to_csv("trainset_alldata_90_target_in.csv" ,index=False)

# %%
test.to_csv("testset_alldata_10_target_in.csv" ,index=False)

# %%
df = pd.read_csv(r"C:\Users\RomarNathoeRepubliq\Documents\Uni\Thesis\Genes\Scripts\testset_alldata_10_target_in.csv")

# %%
df.head()
# Out:
#        PAX8        CCL5       MMP14  DTX2P1-UPK3BP1-PMS2P11         BAD  \
# 0  8.272890    8.039990    6.929590                8.669610    5.418950
# 1  8.317070    8.059250    6.440280                8.315950    5.086590
# 2  8.694966    7.724316    7.389008                8.953354    5.880726
# 3  4.283865  647.917020  159.238638              482.120545  337.385907
# 4  8.914766    5.284705    7.834108                9.194278    7.039463
#
#          PRPF8       CAPNS1         RPL35        EIF4G2        EIF3D  ...  \
# 0     9.898920    10.749400     12.695300      5.544360    11.022000  ...
# 1    10.581600    11.465500     11.797800      5.207860    10.932400  ...
# 2    10.899866    11.275128     11.228692     11.966718    11.525954  ...
# 3  8935.033125  7363.715251  15385.499608  42935.620246  8295.192527  ...
# 4    10.770860    10.630655     11.966666     11.365422    11.308982  ...
#
#        RABEP2       FKBP15        LRCH4      MEX3D      BCAN           ACTB  \
# 0    7.595220     3.419600     8.560160   4.088040  7.552860      12.206000
# 1    7.115450     5.146010     7.639800   5.068390  6.868970      13.889400
# 2    6.979153     5.241102    10.799278   4.569548  7.439056      13.351178
# 3  450.041660  3731.482765  4042.060376  72.524550  1.018917  158039.594917
# 4    7.336827     4.283219    10.352194   5.784377  7.772894      12.494687
#
#            GAPDH  MIR3648-2  MIR3648-1  target
# 0      13.182400   5.965410   5.321470       1
# 1      13.466800   6.839590   5.876310       1
# 2      13.108710  12.235879   9.016586       1
# 3  111180.463745   1.099411   1.099411       1
# 4      12.891293   5.499288   6.207734       0
#
# [5 rows x 12709 columns]
