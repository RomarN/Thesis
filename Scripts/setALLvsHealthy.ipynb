# %%
import pandas as pd
random_state = 7

# %%
df = pd.read_csv(r"C:\Users\RomarNathoeRepubliq\Documents\Uni\Thesis\Genes\Data\datasets123_allinfo.csv")
# df = pd.read_csv(r"C:\Users\Romar\OneDrive\Documenten\Thesis\Test\Data\datasets123_allinfo.csv")

# %%
df.head()
# Out:
#    Dataset        GSE Condition Disease      Tissue      FAB  \
# 0      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
# 1      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
# 2      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
# 3      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
# 4      1.0  Haferlach   CONTROL     ALL  BM or PBMC  unknown
#
#                          Filename                              id      PAX8  \
# 0   AHW_ALL_BA_025919_13_A_PZ.CEL   AHW_ALL_BA_025919_13_A_PZ.CEL  9.221573
# 1   AHW_ALL_BA_032751_71_A_PZ.CEL   AHW_ALL_BA_032751_71_A_PZ.CEL  8.524435
# 2    AHW_ALL_BN_022495_7_A_PZ.CEL    AHW_ALL_BN_022495_7_A_PZ.CEL  8.606060
# 3  AHW_ALL_MLL_031351_13_A_PZ.CEL  AHW_ALL_MLL_031351_13_A_PZ.CEL  8.841501
# 4  AHW_ALL_MLL_036187_80_A_PZ.CEL  AHW_ALL_MLL_036187_80_A_PZ.CEL  8.882826
#
#        CCL5  ...      WNT6    RABEP2    FKBP15      LRCH4     MEX3D      BCAN  \
# ...

# %%
print(df["Disease"].value_counts())
print()
# Out:
# AML                                         4082
# ALL                                         3466
# healthy                                      907
# CLL                                          770
# COPD                                         323
# JIA                                          293
# MDS                                          267
# MS                                           240
# CML                                          162
# Infection                                    156
# TB.vaccination                               119
# Breast cancer                                109
# Dengue fever                                 101
# endarterectomy operation                      97
# Lyme disease                                  84
# Chronic Allograft Nephropathy                 77
# Diabetes Type I                               74
# AMKL                                          63
# influenca vaccination                         63
# ...

# %%
df = df.loc[df['Disease'].isin(['AML','healthy', 'AMKL'])]

# %%
print(df["Disease"].value_counts())
print()
# Out:
# AML        4082
# healthy     907
# AMKL         63
# Name: Disease, dtype: int64

# %%
df['target'] = [0 if (x == 'healthy') else 1 for x in df['Disease']]

# %%
df.head()
# Out:
#     Dataset        GSE Condition Disease      Tissue      FAB  \
# 51      1.0  Haferlach      CASE     AML  BM or PBMC  unknown
# 52      1.0  Haferlach      CASE     AML  BM or PBMC  unknown
# 53      1.0  Haferlach      CASE     AML  BM or PBMC  unknown
# 54      1.0  Haferlach      CASE     AML  BM or PBMC  unknown
# 55      1.0  Haferlach      CASE     AML  BM or PBMC  unknown
#
#                           Filename                              id      PAX8  \
# 51   ALK_AML_aa_033949_63_A_PZ.CEL   ALK_AML_aa_033949_63_A_PZ.CEL  8.502866
# 52  ALK_AML_com_001171_40_A_PZ.CEL  ALK_AML_com_001171_40_A_PZ.CEL  8.718331
# 53  ALK_AML_com_020894_99_A_PZ.CEL  ALK_AML_com_020894_99_A_PZ.CEL  8.678028
# 54  ALK_AML_com_034881_45_A_PZ.CEL  ALK_AML_com_034881_45_A_PZ.CEL  8.634034
# 55   ALK_AML_M2_000167_51_A_PZ.CEL   ALK_AML_M2_000167_51_A_PZ.CEL  8.731049
#
#         CCL5  ...    RABEP2    FKBP15      LRCH4     MEX3D      BCAN  \
# ...

# %%
print(df["target"].value_counts())
print()
# Out:
# 1    4145
# 0     907
# Name: target, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, test_size=0.2, random_state=random_state, stratify=df[['target']])

# %%
train.head()
# Out:
#        Dataset       GSE Condition  Disease      Tissue      FAB  \
# 3344       2.0  GSE61804      CASE      AML          BM  unknown
# 10110      2.0  GSE27383   CONTROL  healthy        PBMC  unknown
# 9349       2.0  GSE17855      CASE      AML  BM or PBMC  unknown
# 9432       2.0  GSE17855      CASE      AML  BM or PBMC  unknown
# 9411       2.0  GSE17855      CASE      AML  BM or PBMC  unknown
#
#                        Filename                        id     PAX8      CCL5  \
# 3344   GSM1514045_MUC_00053.CEL  GSM1514045_MUC_00053.CEL  7.77527   9.77201
# 10110       GSM677180_H28_2.CEL       GSM677180_H28_2.CEL  7.30211  12.07250
# 9349              GSM445992.CEL             GSM445992.CEL  8.31179   9.55874
# 9432              GSM446075.CEL             GSM446075.CEL  8.34763   6.95009
# 9411              GSM446054.CEL             GSM446054.CEL  8.32568   8.06742
#
#        ...   RABEP2   FKBP15    LRCH4    MEX3D     BCAN     ACTB    GAPDH  \
# ...

# %%
test.head()
# Out:
#        Dataset                  GSE Condition Disease      Tissue      FAB  \
# 165        1.0             GSE43176      CASE     AML  BM or PBMC       M2
# 597        1.0              GSE1159      CASE     AML  BM or PBMC  unknown
# 9897       2.0             GSE22845      CASE     AML          BM  unknown
# 11290      3.0  Lavallee (GSE66917)      CASE     AML          BM  unknown
# 10514      2.0             GSE35784      CASE     AML  BM or PBMC       M2
#
#                                  Filename                                  id  \
# 165    GSM1057881_JD0075.AMD.v5.U133A.CEL  GSM1057881_JD0075.AMD.v5.U133A.CEL
# 597                          GSM20740.CEL                        GSM20740.CEL
# 9897                        GSM564613.CEL                       GSM564613.CEL
# 11290                          GSM1634290                          GSM1634290
# 10514                       GSM874805.CEL                       GSM874805.CEL
#
# ...

# %%
print(train["target"].value_counts())
print()
print(test["target"].value_counts())
print()
# Out:
# 1    3316
# 0     725
# Name: target, dtype: int64
#
# 1    829
# 0    182
# Name: target, dtype: int64

# %%
train = train.drop(["Dataset", "GSE", "Condition", "Disease", "Tissue", "FAB", "Filename", "id"], axis = 1)

# %%
test = test.drop(["Dataset", "GSE", "Condition", "Disease", "Tissue", "FAB", "Filename", "id"], axis = 1)

# %%
train.to_csv("trainset_AMLvsHealhy_80_target_in.csv" ,index=False)

# %%
test.to_csv("testset_AMLvsHealthy_20_target_in.csv" ,index=False)

# %%
df = pd.read_csv(r"C:\Users\RomarNathoeRepubliq\Documents\Uni\Thesis\Genes\Scripts\testset_AMLvsALL_10_target_in.csv")

# %%
df.head()
# Out:
#         PAX8        CCL5       MMP14  DTX2P1-UPK3BP1-PMS2P11         BAD  \
# 0   8.720410    5.501740    7.590000                8.838480    5.524840
# 1   7.264660    8.028320    5.950860                6.901030    4.524320
# 2   8.646560    6.013041    7.673210                8.778626    6.138181
# 3   8.327120    7.616320    7.301940                8.790960    4.876120
# 4  19.025931  855.347758  535.295136             1835.096944  753.684895
#
#           PRPF8       CAPNS1        RPL35        EIF4G2        EIF3D  ...  \
# 0      7.859590     8.801500    12.300600      4.677000     9.566820  ...
# 1      7.636460     7.528460    10.365100      6.487810     9.170910  ...
# 2     10.268009    10.693227    12.018947     10.919042    11.534833  ...
# 3     10.102600    10.938600    12.851000      4.617460    11.275500  ...
# 4  24304.922250  3542.132367  9870.423624  33475.082339  6999.606531  ...
#
#        RABEP2       FKBP15        LRCH4      MEX3D      BCAN           ACTB  \
# ...
