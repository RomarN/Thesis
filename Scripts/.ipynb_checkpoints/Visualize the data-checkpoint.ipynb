# %%
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
path = os.getcwd()
parent = os.path.dirname(path)

df = pd.read_csv(parent + "/Data/datasets123_allinfo.csv")

# %%
df.describe()
# Out:
#             Dataset          PAX8          CCL5         MMP14  \
# count  12029.000000  12029.000000  12029.000000  12029.000000
# mean       1.890348     20.941601    500.610596     44.991606
# std        0.542228     60.755856   2324.510348    323.663196
# min        1.000000      0.000000      3.414310      0.000000
# 25%        2.000000      7.364660      7.041345      5.998810
# 50%        2.000000      7.798110      8.862870      6.469090
# 75%        2.000000      8.651520     10.966500      7.778435
# max        3.000000    884.741660  68188.353772  17112.000615
#
#        DTX2P1-UPK3BP1-PMS2P11           BAD         PRPF8        CAPNS1  \
# count            12029.000000  12029.000000  12029.000000  12029.000000
# mean                92.672519     42.115167   1379.289018    742.764311
# std                296.800816    147.947447   4611.631478   2521.659592
# min                  4.849300      0.000000      3.297520      4.644450
# 25%                  7.703900      5.725590      9.299770     10.166600
# 50%                  8.106810      6.186120      9.761810     10.746800
# 75%                  9.052153      6.681220     10.217066     11.265368
# max               5471.067600   4313.991977  62562.771623  28831.262135
#
#               RPL35         EIF4G2  ...          WNT6        RABEP2  \
# count  12029.000000   12029.000000  ...  12029.000000  12029.000000
# mean    1254.529117    3167.076753  ...      6.942278     86.396755
# std     4873.616060   11387.614856  ...      4.357467    283.167265
# min        4.702760       3.153510  ...      0.000000      0.000000
# 25%       11.903243       4.763720  ...      5.803730      6.704750
# 50%       12.754800       5.368760  ...      6.300510      7.428940
# 75%       13.025300      11.082490  ...      7.822166      8.411390
# max    93048.852063  415704.607564  ...    147.536978   4605.516499
#
#              FKBP15         LRCH4         MEX3D          BCAN          ACTB  \
# count  12029.000000  12029.000000  12029.000000  12029.000000  1.202900e+04
# mean     380.231603    515.227878     10.561714      6.627407  1.532902e+04
# std     1308.571371   1694.509931     26.659794      3.156989  6.445140e+04
# min        2.801630      3.875830      0.000000      0.000000  4.609110e+00
# 25%        3.962010      7.352170      3.760010      6.539330  1.088890e+01
# 50%        4.332670      7.879880      4.195550      6.846740  1.221860e+01
# 75%        5.243940      9.652448      5.073400      7.417090  1.323277e+01
# max    13074.885976  17318.187541    543.251633    196.063671  1.481411e+06
#
#                GAPDH     MIR3648-2     MIR3648-1
# count   12029.000000  12029.000000  12029.000000
# mean     6087.272705      7.323981      7.139713
# std     24417.757507      3.248757      3.024066
# min         4.780910      0.000000      0.000000
# 25%        11.984600      5.344862      5.463300
# 50%        12.615600      7.066310      7.160630
# 75%        13.089000      9.456870      8.902450
# max    447418.111281     34.196249     34.196249
#
# [8 rows x 12709 columns]

# %%
df
# Out:
#        Dataset              GSE Condition  Disease      Tissue      FAB  \
# 0          1.0        Haferlach   CONTROL      ALL  BM or PBMC  unknown
# 1          1.0        Haferlach   CONTROL      ALL  BM or PBMC  unknown
# 2          1.0        Haferlach   CONTROL      ALL  BM or PBMC  unknown
# 3          1.0        Haferlach   CONTROL      ALL  BM or PBMC  unknown
# 4          1.0        Haferlach   CONTROL      ALL  BM or PBMC  unknown
# ...        ...              ...       ...      ...         ...      ...
# 12024      3.0  Chen (GSE32874)   CONTROL  healthy        PBMC  unknown
# 12025      3.0  Chen (GSE32874)   CONTROL  healthy        PBMC  unknown
# 12026      3.0  Chen (GSE32874)   CONTROL  healthy        PBMC  unknown
# 12027      3.0  Chen (GSE32874)   CONTROL  healthy        PBMC  unknown
# 12028      3.0  Chen (GSE32874)   CONTROL  healthy        PBMC  unknown
#
#                              Filename                              id  \
# 0       AHW_ALL_BA_025919_13_A_PZ.CEL   AHW_ALL_BA_025919_13_A_PZ.CEL
# 1       AHW_ALL_BA_032751_71_A_PZ.CEL   AHW_ALL_BA_032751_71_A_PZ.CEL
# 2        AHW_ALL_BN_022495_7_A_PZ.CEL    AHW_ALL_BN_022495_7_A_PZ.CEL
# 3      AHW_ALL_MLL_031351_13_A_PZ.CEL  AHW_ALL_MLL_031351_13_A_PZ.CEL
# 4      AHW_ALL_MLL_036187_80_A_PZ.CEL  AHW_ALL_MLL_036187_80_A_PZ.CEL
# ...                               ...                             ...
# 12024                       GSM818578                       GSM818578
# 12025                       GSM818579                       GSM818579
# 12026                       GSM818580                       GSM818580
# 12027                       GSM818581                       GSM818581
# 12028                       GSM818582                       GSM818582
#
#             PAX8          CCL5  ...       WNT6       RABEP2       FKBP15  \
# 0       9.221573      7.990144  ...   9.725984     6.468604     4.229163
# 1       8.524435      6.648112  ...   8.805910     7.236525     4.594555
# 2       8.606060      6.382602  ...   9.142436     7.937021     4.173806
# 3       8.841501      6.469583  ...   9.169173     8.361242     4.577759
# 4       8.882826      8.332415  ...   8.948210     8.229147     4.181408
# ...          ...           ...  ...        ...          ...          ...
# 12024  20.825264  52756.882123  ...  17.383274  1199.186375  1985.982540
# 12025  29.365382  53887.099471  ...  22.098298  1203.800161  1847.846786
# 12026  51.908386  31899.374172  ...  38.638898  1491.998086  2709.743224
# 12027  28.497605  48650.041199  ...  25.278220  1277.347219  1774.944031
# 12028  30.933276  58033.027074  ...  21.792370   754.937522  2075.042227
#
#              LRCH4       MEX3D       BCAN           ACTB         GAPDH  \
# 0         9.617773    5.404848   7.871873      11.430549     11.725073
# 1         9.652448    5.650710   7.179527      10.928578     11.671908
# 2         9.792847    5.385639   7.652625      11.297186     11.879521
# 3        10.470295    5.696314   7.594891      12.156462     12.175835
# 4        10.439300    5.459417   7.480463      10.509088     11.038747
# ...            ...         ...        ...            ...           ...
# 12024  8709.585092  366.229532  15.799664  557891.266013  91281.914860
# 12025  7449.730459  279.114924   1.145053  604300.301194  74882.837794
# 12026  8630.081042  259.854282   4.896505  558270.189139  82491.523183
# 12027  6414.229718  301.727183   1.331091  900765.910193  68371.108311
# 12028  6814.102528  338.224868   1.375970  799722.741338  95163.496287
#
#        MIR3648-2  MIR3648-1
# 0       6.373859   6.086670
# 1       6.572640   7.823704
# 2      11.165859  10.734375
# 3       9.551800   9.627878
# 4      11.295602  10.229529
# ...          ...        ...
# 12024   3.157836   3.157836
# 12025   0.000000   0.000000
# 12026   1.831075   1.831075
# 12027  14.432087  14.432087
# 12028   6.786497   6.786497
#
# [12029 rows x 12716 columns]

# %%
disease_freq = df.Disease.value_counts()

# %%
x_other_diseases = []
y_other_diseases = []
for i in range(len(disease_freq)):
    if disease_freq[i] > 100 and disease_freq.index[i] not in ["ALL", "AML", "healthy"]: 
        x_other_diseases.append(disease_freq.index[i])
        y_other_diseases.append(disease_freq[i])

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.barplot(x=x_other_diseases, y=y_other_diseases)
plt.savefig(parent + '/Figures/other_diseases.eps',
           dpi=300)

# %%
x_aml_cll_all= []
y_aml_cll_all = []
for i in range(len(disease_freq)):
    if disease_freq[i] > 500 and disease_freq.index[i] not in ["healthy"]: 
        x_aml_cll_all.append(disease_freq.index[i])
        y_aml_cll_all.append(disease_freq[i])

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.barplot(x=x_aml_cll_all, y=y_aml_cll_all)
plt.savefig(parent + '/Figures/aml_all_cll.eps',
           dpi=300)

# %%
x_aml_healthy= []
y_aml_healthy = []
for i in range(len(disease_freq)):
    if disease_freq[i] > 800 and disease_freq.index[i] not in ["ALL"]: 
        x_aml_healthy.append(disease_freq.index[i])
        y_aml_healthy.append(disease_freq[i])

sns.set(rc = {'figure.figsize':(15,8)})
sns.barplot(x=x_aml_healthy, y=y_aml_healthy)
plt.savefig(parent + '/Figures/aml_healthy.eps',
           dpi=300)

# %%
# define Seaborn color palette to use
palette_color = sns.color_palette('deep')
  
# plotting data on chart
plt.pie(y_aml_healthy, labels=x_aml_healthy, colors=palette_color, autopct='%.0f%%', explode = [0,.2])
  
# displaying chart
plt.show()

# %%
x_all_healthy= []
y_all_healthy = []
for i in range(len(disease_freq)):
    if disease_freq[i] > 800 and disease_freq.index[i] not in ["AML"]: 
        x_all_healthy.append(disease_freq.index[i])
        y_all_healthy.append(disease_freq[i])

sns.set(rc = {'figure.figsize':(15,8)})
sns.barplot(x=x_all_healthy, y=y_all_healthy)
plt.savefig(parent + '/Figures/all_healthy.eps',
           dpi=300)

# %%
df
# Out:
#        Dataset              GSE Condition  Disease      Tissue      FAB  \
# 0          1.0        Haferlach   CONTROL      ALL  BM or PBMC  unknown
# 1          1.0        Haferlach   CONTROL      ALL  BM or PBMC  unknown
# 2          1.0        Haferlach   CONTROL      ALL  BM or PBMC  unknown
# 3          1.0        Haferlach   CONTROL      ALL  BM or PBMC  unknown
# 4          1.0        Haferlach   CONTROL      ALL  BM or PBMC  unknown
# ...        ...              ...       ...      ...         ...      ...
# 12024      3.0  Chen (GSE32874)   CONTROL  healthy        PBMC  unknown
# 12025      3.0  Chen (GSE32874)   CONTROL  healthy        PBMC  unknown
# 12026      3.0  Chen (GSE32874)   CONTROL  healthy        PBMC  unknown
# 12027      3.0  Chen (GSE32874)   CONTROL  healthy        PBMC  unknown
# 12028      3.0  Chen (GSE32874)   CONTROL  healthy        PBMC  unknown
#
#                              Filename                              id  \
# 0       AHW_ALL_BA_025919_13_A_PZ.CEL   AHW_ALL_BA_025919_13_A_PZ.CEL
# 1       AHW_ALL_BA_032751_71_A_PZ.CEL   AHW_ALL_BA_032751_71_A_PZ.CEL
# 2        AHW_ALL_BN_022495_7_A_PZ.CEL    AHW_ALL_BN_022495_7_A_PZ.CEL
# 3      AHW_ALL_MLL_031351_13_A_PZ.CEL  AHW_ALL_MLL_031351_13_A_PZ.CEL
# 4      AHW_ALL_MLL_036187_80_A_PZ.CEL  AHW_ALL_MLL_036187_80_A_PZ.CEL
# ...                               ...                             ...
# 12024                       GSM818578                       GSM818578
# 12025                       GSM818579                       GSM818579
# 12026                       GSM818580                       GSM818580
# 12027                       GSM818581                       GSM818581
# 12028                       GSM818582                       GSM818582
#
#             PAX8          CCL5  ...       WNT6       RABEP2       FKBP15  \
# 0       9.221573      7.990144  ...   9.725984     6.468604     4.229163
# 1       8.524435      6.648112  ...   8.805910     7.236525     4.594555
# 2       8.606060      6.382602  ...   9.142436     7.937021     4.173806
# 3       8.841501      6.469583  ...   9.169173     8.361242     4.577759
# 4       8.882826      8.332415  ...   8.948210     8.229147     4.181408
# ...          ...           ...  ...        ...          ...          ...
# 12024  20.825264  52756.882123  ...  17.383274  1199.186375  1985.982540
# 12025  29.365382  53887.099471  ...  22.098298  1203.800161  1847.846786
# 12026  51.908386  31899.374172  ...  38.638898  1491.998086  2709.743224
# 12027  28.497605  48650.041199  ...  25.278220  1277.347219  1774.944031
# 12028  30.933276  58033.027074  ...  21.792370   754.937522  2075.042227
#
#              LRCH4       MEX3D       BCAN           ACTB         GAPDH  \
# 0         9.617773    5.404848   7.871873      11.430549     11.725073
# 1         9.652448    5.650710   7.179527      10.928578     11.671908
# 2         9.792847    5.385639   7.652625      11.297186     11.879521
# 3        10.470295    5.696314   7.594891      12.156462     12.175835
# 4        10.439300    5.459417   7.480463      10.509088     11.038747
# ...            ...         ...        ...            ...           ...
# 12024  8709.585092  366.229532  15.799664  557891.266013  91281.914860
# 12025  7449.730459  279.114924   1.145053  604300.301194  74882.837794
# 12026  8630.081042  259.854282   4.896505  558270.189139  82491.523183
# 12027  6414.229718  301.727183   1.331091  900765.910193  68371.108311
# 12028  6814.102528  338.224868   1.375970  799722.741338  95163.496287
#
#        MIR3648-2  MIR3648-1
# 0       6.373859   6.086670
# 1       6.572640   7.823704
# 2      11.165859  10.734375
# 3       9.551800   9.627878
# 4      11.295602  10.229529
# ...          ...        ...
# 12024   3.157836   3.157836
# 12025   0.000000   0.000000
# 12026   1.831075   1.831075
# 12027  14.432087  14.432087
# 12028   6.786497   6.786497
#
# [12029 rows x 12716 columns]

# %%
df["PAX8"].describe()
# Out:
# count    12029.000000
# mean        20.941601
# std         60.755856
# min          0.000000
# 25%          7.364660
# 50%          7.798110
# 75%          8.651520
# max        884.741660
# Name: PAX8, dtype: float64

# %%
df["CCL5"].describe()
# Out:
# count    12029.000000
# mean       500.610596
# std       2324.510348
# min          3.414310
# 25%          7.041345
# 50%          8.862870
# 75%         10.966500
# max      68188.353772
# Name: CCL5, dtype: float64

# %%
y = [0.9969,0.9973,0.9971,0.9975,0.9982,0.9976,0.9978]
x = ['50', '75', '100', '125', '150', '175' , '200']

# %%
sns.set(rc = {'figure.figsize':(15,8)})
plot = sns.barplot(x=x, y=y)
plot.set( xlabel = "Value for N", ylabel = "F1 Score")
plot.set(ylim=(0.98, 1))
plt.savefig(parent + '/Figures/all_healthy_F1_score_N.eps',
           dpi=300)

# %%
import seaborn as sns
